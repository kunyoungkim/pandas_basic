# %% [markdown]
# <a href="https://colab.research.google.com/github/kunyoungkim/pandas_basic/blob/main/concat().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# 두 개의 데이터프레임 생성
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                    'B': ['B0', 'B1', 'B2']})

df2 = pd.DataFrame({'A': ['A3', 'A4', 'A5'],
                    'B': ['B3', 'B4', 'B5']})

# 행(row) 기준 병합
pd.concat([df1, df2], axis=0)
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 0  A3  B3
# 1  A4  B4
# 2  A5  B5

# %%
# 열(column) 기준 병합
pd.concat([df1, df2], axis=1)
# Out:
#     A   B   A   B
# 0  A0  B0  A3  B3
# 1  A1  B1  A4  B4
# 2  A2  B2  A5  B5

# %%
# ignore_index=True 예시
pd.concat([df1, df2], ignore_index=True)
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 4  A4  B4
# 5  A5  B5

# %%
# inner 조인으로 병합
df3 = pd.DataFrame({'A': ['A0', 'A1'],
                    'C': ['C0', 'C1']})

pd.concat([df1, df3], axis=1, join='inner')
# Out:
#     A   B   A   C
# 0  A0  B0  A0  C0
# 1  A1  B1  A1  C1

# %%
# 시리즈와 병합
s1 = pd.Series(['X0', 'X1', 'X2'], name='X')

pd.concat([df1, s1], axis=1)
# Out:
#     A   B   X
# 0  A0  B0  X0
# 1  A1  B1  X1
# 2  A2  B2  X2

# %%
# keys 옵션 사용 예시
pd.concat([df1, df2], keys=['df1', 'df2'])
# Out:
#         A   B
# df1 0  A0  B0
#     1  A1  B1
#     2  A2  B2
# df2 0  A3  B3
#     1  A4  B4
#     2  A5  B5

# %%
# levels 옵션 사용 예시
pd.concat([df1, df2], keys=['df1', 'df2'], levels=[['df1', 'df2']])
# Out:
#         A   B
# df1 0  A0  B0
#     1  A1  B1
#     2  A2  B2
# df2 0  A3  B3
#     1  A4  B4
#     2  A5  B5

# %%
# names 옵션 사용 예시
pd.concat([df1, df2], keys=['df1', 'df2'], names=['DataFrame'])
# Out:
#               A   B
# DataFrame
# df1       0  A0  B0
#           1  A1  B1
#           2  A2  B2
# df2       0  A3  B3
#           1  A4  B4
#           2  A5  B5

# %%
pd.concat([df1, df2], axis=1, sort=True)
# Out:
#     A   B   A   B
# 0  A0  B0  A3  B3
# 1  A1  B1  A4  B4
# 2  A2  B2  A5  B5

# %%
# verify_integrity=True로 중복 인덱스를 허용하지 않음
pd.concat([df1, df2], verify_integrity=True)  # 오류 발생 가능
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-60370496d826> in <cell line: 2>()
#       1 # verify_integrity=True로 중복 인덱스를 허용하지 않음
# ----> 2 pd.concat([df1, df2], verify_integrity=True)  # 오류 발생 가능
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     391     )
#     392
# --> 393     return op.get_result()
#     394
#     395
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in get_result(self)
#     665             for obj in self.objs:
#     666                 indexers = {}
# --> 667                 for ax, new_labels in enumerate(self.new_axes):
#     668                     # ::-1 to convert BlockManager ax to DataFrame ax
#     669                     if ax == self.bm_axis:
#
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/kunyoungkim/pandas_basic/blob/main/groupby().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.groupby('survived')['fare'].sum()
# Out:
# survived
# 0    12142.7199
# 1    16551.2294
# Name: fare, dtype: float64

# %%
df.groupby(['survived','sex'])['fare'].mean()
# Out:
# survived  sex
# 0         female    23.024385
#           male      21.960993
# 1         female    51.938573
#           male      40.821484
# Name: fare, dtype: float64

# %%
df.groupby('survived')['fare'].max()
# Out:
# survived
# 0    0.0
# 1    0.0
# Name: fare, dtype: float64

# %%
# 사용자 정의 함수를 적용하여 그룹화된 데이터에 적용하기
def custom_function(x):
    return x.max() - x.min()

df.groupby('survived')['fare'].agg(custom_function)
# Out:
# survived
# 0    263.0000
# 1    512.3292
# Name: fare, dtype: float64

# %%
df.groupby('survived')['fare'].agg(lambda x: x.max() - x.min())
# Out:
# survived
# 0    263.0000
# 1    512.3292
# Name: fare, dtype: float64

# %%
df.groupby(['survived'])['fare'].agg(['mean', lambda x : x.max() - x.min()]).rename(columns = {'<lambda_0>': 'range'})
# Out:
#                mean     range
# survived
# 0         22.117887  263.0000
# 1         48.395408  512.3292

# %%
df.groupby(['survived', 'sex']).agg({'fare':'mean', 'age':'max'})
# Out:
#                       fare   age
# survived sex
# 0        female  23.024385  57.0
#          male    21.960993  74.0
# 1        female  51.938573  63.0
#          male    40.821484  80.0

# %%
df.groupby(['survived', 'sex'],as_index=False).agg({'fare':'mean', 'age':'max'})
# Out:
#    survived     sex       fare   age
# 0         0  female  23.024385  57.0
# 1         0    male  21.960993  74.0
# 2         1  female  51.938573  63.0
# 3         1    male  40.821484  80.0

# %%
df.groupby(['survived', 'sex']).agg({'fare':'mean', 'age':'max'}).reset_index()
# Out:
#    survived     sex       fare   age
# 0         0  female  23.024385  57.0
# 1         0    male  21.960993  74.0
# 2         1  female  51.938573  63.0
# 3         1    male  40.821484  80.0

# %%
df
# Out:
#                       fare   age
# survived sex
# 0        female  23.024385  57.0
#          male    21.960993  74.0
# 1        female  51.938573  63.0
#          male    40.821484  80.0

# %%
df = df.groupby(['survived', 'sex'],dropna=False).agg({'fare':'mean', 'age':'max'})

# %%
df
# Out:
#                       fare   age
# survived sex
# 0        female  23.024385  57.0
#          male    21.960993  74.0
# 1        female  51.938573  63.0
#          male    40.821484  80.0

# %%
df.groupby(level=1).sum()
# Out:
#              fare    age
# sex
# female  74.962959  120.0
# male    62.782477  154.0

# %%
import numpy as np
import pandas as pd

data = {
    'index' : ['A', 'A', 'A', np.nan, 'B', 'B', 'B'],
    'value' : [1,2,3,4,5,6,7]
}

df = pd.DataFrame(data)
df
# Out:
#   index  value
# 0     A      1
# 1     A      2
# 2     A      3
# 3   NaN      4
# 4     B      5
# 5     B      6
# 6     B      7

# %%
df.groupby('index',dropna=False).mean()
# Out:
#        value
# index
# A        2.0
# B        6.0
# NaN      4.0
